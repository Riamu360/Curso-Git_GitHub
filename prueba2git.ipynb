# %% [markdown]
# Subida de otro archivo al repositorio:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Intento de merge:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Eliminación de una rama

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Clonación de un repositorio a través de Git:

# %% [markdown]
# ![image.png](attachment:image.png)
